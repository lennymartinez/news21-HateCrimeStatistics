# %% [markdown]
# # Tidying up the FBI's Hate Crime Statistics
#
# I'm working with tables 13 and 14 of the FBI's Hate Crime Statistics for the years 2010–2016. The goal now is to tidy the data before going to work with Hari to visualize it.

# %%
import csv
with open('fbiMain.csv','r') as f:
    reader = csv.reader(f, delimiter=',')
    rows = [row for row in reader]

# %%
rows
# Out:
# [['year', 'state', 'agencyName', 'q01', 'q02', 'q03', 'q04', 'population'],
#  ['2010', 'Alabama', 'Abbeville', '0', 'DNR', '0', 'DNR', '2950'],
#  ['2010', 'Georgia', 'Abbeville', '0', '0', 'DNR', 'DNR', '2828'],
#  ['2010', 'South Carolina', 'Abbeville', '0', '0', '0', '0', '5443'],
#  ['2011', 'South Carolina', 'Abbeville', '0', '0', '1', '0', '5298'],
#  ['2011', 'Georgia', 'Abbeville', '0', '0', '0', '0', '2946'],
#  ['2012', 'Georgia', 'Abbeville', '0', '0', '0', 'DNR', '2946'],
#  ['2012', 'South Carolina', 'Abbeville', '0', '0', '0', '0', '5232'],
#  ['2013', 'Georgia', 'Abbeville', '0', '0', '0', '0', '2888'],
#  ['2013', 'South Carolina', 'Abbeville', '0', '0', '0', '0', '5163'],
#  ['2014', 'South Carolina', 'Abbeville', '0', '0', '1', '0', '5163'],
#  ['2014', 'Georgia', 'Abbeville', '0', '0', '0', '0', '2869'],
#  ['2015', 'Georgia', 'Abbeville', '0', '0', '0', '0', '2784'],
#  ['2015', 'South Carolina', 'Abbeville', '0', ' DNR', ' DNR', ' DNR', '5173'],
# ...

# %%
tidy = ["year","state","city","quarter","population"]

oldhead = rows[0]
sample = rows[1]

for i in range(0,len(oldhead)):
    year = sample[0]
    state = sample[1]
    city = sample[2]
    q1 = sample[3]
    q2 = sample[4]
    q3 = sample[5]
    q6 = sample[6]
# Out:
# 2010
# Alabama
# Abbeville
# 0
# DNR
# 0
# DNR
# 2950
